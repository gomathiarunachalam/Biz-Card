# %%
pip install easyocr
# Out:
# Collecting easyocrNote: you may need to restart the kernel to use updated packages.
#
#   Downloading easyocr-1.7.0-py3-none-any.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\vijay anand\anaconda3\lib\site-packages (from easyocr) (1.21.5)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (38.0 MB)
#      ---------------------------------------- 38.0/38.0 MB 2.7 MB/s eta 0:00:00
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
#      -------------------------------------- 313.0/313.0 kB 2.4 MB/s eta 0:00:00
# Collecting torchvision>=0.5
#   Downloading torchvision-0.15.2-cp39-cp39-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in c:\users\vijay anand\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: scipy in c:\users\vijay anand\anaconda3\lib\site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: PyYAML in c:\users\vijay anand\anaconda3\lib\site-packages (from easyocr) (6.0)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post4-cp39-cp39-win_amd64.whl (95 kB)
#      ---------------------------------------- 95.1/95.1 kB 2.7 MB/s eta 0:00:00
# Collecting Shapely
#   Downloading shapely-2.0.1-cp39-cp39-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in c:\users\vijay anand\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Collecting torch
#   Downloading torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
#      -------------------------------------- 172.4/172.4 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\vijay anand\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: jinja2 in c:\users\vijay anand\anaconda3\lib\site-packages (from torch->easyocr) (2.11.3)
# Requirement already satisfied: filelock in c:\users\vijay anand\anaconda3\lib\site-packages (from torch->easyocr) (3.6.0)
# Requirement already satisfied: typing-extensions in c:\users\vijay anand\anaconda3\lib\site-packages (from torch->easyocr) (4.3.0)
# Requirement already satisfied: networkx in c:\users\vijay anand\anaconda3\lib\site-packages (from torch->easyocr) (2.8.4)
# Requirement already satisfied: sympy in c:\users\vijay anand\anaconda3\lib\site-packages (from torch->easyocr) (1.10.1)
# Requirement already satisfied: six in c:\users\vijay anand\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\vijay anand\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\vijay anand\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\vijay anand\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\vijay anand\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vijay anand\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vijay anand\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijay anand\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vijay anand\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijay anand\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vijay anand\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vijay anand\anaconda3\lib\site-packages (from sympy->torch->easyocr) (1.2.1)
# Installing collected packages: pyclipper, ninja, Shapely, python-bidi, opencv-python-headless, torch, torchvision, easyocr
# Successfully installed Shapely-2.0.1 easyocr-1.7.0 ninja-1.11.1 opencv-python-headless-4.8.0.74 pyclipper-1.3.0.post4 python-bidi-0.4.2 torch-2.0.1 torchvision-0.15.2

# %%
# ===============================================   /   /   Import library   /   /   ========================================= #
import pandas as pd
import numpy as np


# [Scanning library]
import easyocr # (Optical Character Recognition)
import cv2
import PIL
from PIL import Image, ImageDraw
import os
import re

# [Database library]
import mysql.connector

# [Dashboard library]
# import streamlit as st

# %%
# import image
import_image = PIL.Image.open('1.jpeg')
import_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1004x590>

# %%
if import_image is not None:
    try:
        # Create the reader object with desired languages
        reader = easyocr.Reader(['en'], gpu=True)
    except ModuleNotFoundError:
        print("Error: easyocr module is not installed. Please install it.")
        
    try:
        # Read the image file as a PIL Image object
        if isinstance(import_image, str):
            image = Image.open(import_image)
        elif isinstance(import_image, Image.Image):
            image = import_image
        else:
            raise ValueError("Invalid image format. Please provide a file path or a PIL Image object.")

        # Convert the image to a numpy array
        image_array = np.array(image)

        # Perform OCR on the image
        text_read = reader.readtext(image_array)

        # Extract the text
        #result = [text[1] for text in text_read]
        result = []
        for text in text_read:
            result.append(text[1])

        # Convert the result to the desired format
        #formatted_result = "\n".join(result)
        #print(formatted_result)

    except Exception as e:
        print("Error: Failed to process the image. Please try again with a different image.")
        print(e)
else:
    print("Error: No image provided.")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result
# Out:
# ['Selval',
#  'DATA MANAGER',
#  '+123-456-7890',
#  '+123-456-7891',
#  'WwW XYZIcom',
#  'hhello@XYz1.com',
#  '123 ABC St , Chennai,',
#  'selva',
#  'TamilNadu 600113',
#  'digitals']

# %%
def draw_boxes(import_image, text_read, color='yellow', width=2):
    draw = ImageDraw.Draw(import_image)
    for bound in text_read:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return import_image

result_image = draw_boxes(import_image, text_read)
result_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1004x590>

# %%
# Initialize the data dictionary
data = {
    "company_name": [],
    "card_holder": [],
    "designation": [],
    "mobile_number": [],
    "email": [],
    "website": [],
    "area": [],
    "city": [],
    "state": [],
    "pin_code": [],
}

def get_data(res):
    city = ""  # Initialize the city variable
    for ind, i in enumerate(res):
        # To get WEBSITE_URL
        if "www " in i.lower() or "www." in i.lower():
            data["website"].append(i)
        elif "WWW" in i:
            data["website"].append(res[ind-1] + "." + res[ind])

        # To get EMAIL ID
        elif "@" in i:
            data["email"].append(i)

        # To get MOBILE NUMBER
        elif "-" in i:
            data["mobile_number"].append(i)
            if len(data["mobile_number"]) == 2:
                data["mobile_number"] = " & ".join(data["mobile_number"])

        # To get COMPANY NAME
        elif ind == len(res) - 1:
            data["company_name"].append(i)

        # To get CARD HOLDER NAME
        elif ind == 0:
            data["card_holder"].append(i)

        # To get DESIGNATION
        elif ind == 1:
            data["designation"].append(i)

        # To get AREA
        if re.findall("^[0-9].+, [a-zA-Z]+", i):
            data["area"].append(i.split(",")[0])
        elif re.findall("[0-9] [a-zA-Z]+", i):
            data["area"].append(i)

        # To get CITY NAME
        match1 = re.findall(".+St , ([a-zA-Z]+).+", i)
        match2 = re.findall(".+St,, ([a-zA-Z]+).+", i)
        match3 = re.findall("^[E].*", i)
        if match1:
            city = match1[0]  # Assign the matched city value
        elif match2:
            city = match2[0]  # Assign the matched city value
        elif match3:
            city = match3[0]  # Assign the matched city value

        # To get STATE
        state_match = re.findall("[a-zA-Z]{9} +[0-9]", i)
        if state_match:
            data["state"].append(i[:9])
        elif re.findall("^[0-9].+, ([a-zA-Z]+);", i):
            data["state"].append(i.split()[-1])
        if len(data["state"]) == 2:
            data["state"].pop(0)

        # To get PINCODE
        if len(i) >= 6 and i.isdigit():
            data["pin_code"].append(i)
        elif re.findall("[a-zA-Z]{9} +[0-9]", i):
            data["pin_code"].append(i[10:])

    data["city"].append(city)  # Append the city value to the 'city' array
    

get_data(result)


df = pd.DataFrame(data)

df.T
# Out:
#                                            0
# company_name                        digitals
# card_holder                           Selval
# designation                     DATA MANAGER
# mobile_number  +123-456-7890 & +123-456-7891
# email                        hhello@XYz1.com
# website                          WwW XYZIcom
# area                             123 ABC St
# city                                 Chennai
# state                              TamilNadu
# pin_code                              600113
